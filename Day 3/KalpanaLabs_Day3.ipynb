# %% [markdown]
# <a href="https://colab.research.google.com/github/ekdnam/KalpanaLabs/blob/master/Day%203/KalpanaLabs_Day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hello all!
#
# Today let us learn about variables!
#
# (This session is in continuation to that conducted on 16th Aug, 2020.)

# %% [markdown]
# # Variables
#
# ## Clash Royale
#
# You all like Clash Royale, right?
#
# ![clash-royale.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# How many games have you played?
#
# How many wins?
#
# **Enter the values below**

# %%
# games played
gamesPlayed = 0 # ENTER VALUE

# games won
gamesWon = 0 # ENTER VALUE

# %% [markdown]
# # Remember!
#
# After changing something written in a ***cell***,
#
# press **Shift and then Enter** to **run** the cell

# %% [markdown]
# # Equation
#
# How many games have you lost?
#
# (An equation is something that looks like **a + b** OR **a - b** OR **a * b**  OR **a / b**)

# %%
# games lost
gamesLost = 0 # ENTER EQUATION

# HINT: gamesWon + ____ = gamesPlayed

# %% [markdown]
# Introducing some new variables which will be needed after some time

# %%
totalGamesPlayed = 0 # ENTER VALUE

totalGamesWon = 0 # ENTER VALUE

totalGamesLost = 0 # ENTER VALUE

# %% [markdown]
# ## Print the values
#
# Use what we learnt last week

# %%
# PRINT GAMES PLAYED


# PRINT GAMES WON


# PRINT GAMES LOST

# %% [markdown]
# ## **Ratios**
#
# Ratios are something like b divides a
#
# ### **Win ratio**
#
# Win ratio is the number of wins upon the total number of games played
#
# ### **Loss ratio**
#
# Loss ratio is the number of losses upon the total number of games played

# %%
winRatio = 0 # ENTER EQUATION

lossRatio = 0 # ENTER EQUATION

# %% [markdown]
# ### **Print the ratios**

# %%
# PRINT WIN RATIO


# PRINT LOSS RATIO

# %% [markdown]
# # Now play the game!

# %% [markdown]
# ## Enter the following:
#
# 1) new games played (value)
#
# 2) games won from them (value)
#
# 3) games lost (equation)

# %%
# new games
newGames = 0 # ENTER VALUE

# new wins
newWins = 0 # ENTER VALUE

# new losses
newLosses = 0 # ENTER EQUATION

# %% [markdown]
# ### Some variables are the same? Or have they changed?

# %% [markdown]
# Give defintion for the new variables (if yes)

# %% [markdown]
# New ratios now?

# %% [markdown]
# Print the new ratios!

# %% [markdown]
# # Variables conclusion
#
# As we have seen, variables are something whose values are not the same, they keep on changing from time to time
#
# (Kohli, Tendulkar, Dhoni)
#
# (People for Aarti at the Ganpati Temple)
#
# (Runs scored in a cricket match)
